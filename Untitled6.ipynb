# %% [markdown]
# # Relax and hold steady - Stokes Flow in vorticity-streamfunction formulation

# %% [markdown]
# ## Introduction théorique

# %% [markdown]
# ### Vorticité

# %% [markdown]
# En commençant par l'équation de Navier Stokes
# $$\frac{\partial u}{\partial t}+u.\nabla u=-\frac{1}{\rho}\nabla\rho+\nu\nabla^2u$$
# où $u$ et $p$ sont respectivement des vitesses et pressions adimentionnelles, nous pouvons en supposant que le nombre de Reynolds correspondant aux conditions approche zéro et en définissant la vorticité
# $$\omega=\nabla\times u$$
# Retirer l'équation de Laplace suivante
# $$\nabla^2\omega=0$$

# %% [markdown]
# ### Fonction de courant

# %% [markdown]
# Définissons la fonction de courant $\psi$ telle que
# $$\frac{\partial\psi}{\partial y}=u~~~~~~~~~~~~-\frac{\partial\psi}{\partial x}=v$$

# %% [markdown]
# A deux dimensions, la vorticité pourra alors s'écrire
# $$\omega=\frac{\partial v}{\partial x}-\frac{\partial u}{\partial y}$$

# %% [markdown]
# Ceci donnant finalement un système de deux équations différentielles couplées :
# $$\nabla^2\psi=-\omega$$
# $$\nabla^2\omega=0$$

# %% [markdown]
# ## Analyse numérique par la méthode de Laplace.

# %%
import numpy
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16

# %% [markdown]
# Commençons par implémentons les données livrées par l'énoncé

# %%
nx = 41
ny = 41

l = 1.
h = 1.

dx = l/(nx-1)
dy = h/(ny-1)

l1_target = 1e-6

# %% [markdown]
# Nous définissons d'une part la fonction L1norm, qui donnera la norme L1 de la différence entre un tabelau et une autre, requise pour le calcul du critère de convergeance. Aussi nous définissons une fonction qui nous permettra de visualiser nos données sous forme d'un gaphique en trois dimensions

# %%
def L1norm(new, old):
    norm = numpy.sum(numpy.abs(new-old))
    return norm

def plot_3D(x, y, p):
    fig = pyplot.figure(figsize=(11,7), dpi=100)
    ax = fig.gca(projection='3d')
    X,Y = numpy.meshgrid(x,y)
    surf = ax.plot_surface(X,Y,p[:], rstride=1, cstride=1, cmap=cm.viridis,
            linewidth=0, antialiased=False)

    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_zlabel('$z$')
    ax.view_init(30,45)

# %% [markdown]
# Enfin nous implémentons les conditions initiales du problème

# %%
x = numpy.linspace(0,l,nx)
y = numpy.linspace(0,h,ny)
O = numpy.zeros((ny,nx))
P = numpy.zeros((ny,nx))
O[-1,:] = (-0.5/(dy**2))*(8*P[-2,:]-P[-3,:])-(3/dy)

# %% [markdown]
# Maintenant, créons une fonction qui ittérera la méthode de Jacobi jusqu'à ce que le critère en norme L1 soit atteint.

# %%
def laplace2d(O, P, dx, dy, l1_target):
    
    Onorm = 1
    Pnorm = 1
    o = numpy.zeros((ny,nx))
    p = numpy.zeros((ny,nx))
    N = 0
    
    while Onorm > l1_target and Pnorm > l1_target:
        o = O.copy()
        p = P.copy()
        
        O[1:-1,1:-1] = 0.25 * (o[1:-1,2:] + o[1:-1, :-2]\
                             + o[2:, 1:-1] + o[:-2, 1:-1])
    
        
        O[-1,:] = -0.5/(dy**2)*(8*P[-2,:]-P[-3,:])-(3/dy) 
        O[0,:] = -0.5/(dy**2)*(8*P[1,:]-P[2,:])
        O[:,-1] = -0.5/(dy**2)*(8*P[:,-2]-P[:,-3])
        O[:,0] = -0.5/(dy**2)*(8*P[:,1]-P[:,2])
        
        P[1:-1,1:-1] = 0.25 * (p[1:-1,2:] + p[1:-1,:-2]\
                              + p[2:,1:-1] + p[:-2,1:-1]\
                              + O[1:-1,1:-1] * dx**2)
        Onorm  = L1norm(O,o)
        Pnorm = L1norm(P,p)
        N += 1

    return O, P, N

# %%
O, P, N = laplace2d(O.copy(), P.copy(), dx, dy, l1_target)

# %%
plot_3D(x,y,P)

# %%
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   1.41427373e-06,   2.17375962e-06, ...,
#           2.17375962e-06,   1.41427373e-06,   0.00000000e+00],
#        [  0.00000000e+00,   2.20498030e-06,   1.46927105e-07, ...,
#           1.46927105e-07,   2.20498030e-06,   0.00000000e+00],
#        ...,
#        [  0.00000000e+00,  -6.35061502e-03,  -1.52288229e-02, ...,
#          -1.52288229e-02,  -6.35061502e-03,   0.00000000e+00],
#        [  0.00000000e+00,  -7.32622360e-03,  -1.33638593e-02, ...,
#          -1.33638593e-02,  -7.32622360e-03,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00]])
